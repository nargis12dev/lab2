# %%
std1 = str(input("enter student 1 full name: "))
std2 = str(input("enter student 2 full name: "))
std3 = str(input("enter student 3 full name: "))
std4 = str(input("enter student 4 full name: "))
std5 = str(input("enter student 5 full name: "))
# Out:
# enter student 1 full name: alishba khan
# enter student 2 full name: alishba ahmed
# enter student 3 full name: alishba iqbal
# enter student 4 full name: saman
# enter student 5 full name: hafsan

# %%
std1inter = float(input("enter percentage: "))
std2inter = float(input("enter percentage: "))
std3inter = float(input("enter percentage: "))
std4inter = float(input("enter percentage: "))
std5inter = float(input("enter percentage: "))
# Out:
# enter percentage: 81
# enter percentage: 78
# enter percentage: 92
# enter percentage: 83
# enter percentage: 86

# %%
std1dob = str(input("enter your date of birth: "))
std2dob = str(input("enter your date of birth: "))
std3dob = str(input("enter your date of birth: "))
std4dob = str(input("enter your date of birth: "))
std5dob = str(input("enter your date of birth: "))
# Out:
# enter your date of birth: 14-5-2003
# enter your date of birth: 15-8-2002
# enter your date of birth: 18-3-2004
# enter your date of birth: 19-2004
# enter your date of birth: 19-6-2004

# %%
std1college = str(input("enter your college name: "))
std2college = str(input("enter your college name: "))
std3college = str(input("enter your college name: "))
std4college = str(input("enter your college name: "))
std5college = str(input("enter your college name: "))
# Out:
# enter your college name: shaikh zaid
# enter your college name: bahria
# enter your college name: aga khan school
# enter your college name: fatimma jinnah
# enter your college name: sir syed

# %%
std_data = str(input("enter student name"))
if (std_data == "alishba kha ") or (std_data == "alishba") or (std_data == "alishbakhan") or (std_data == "alishba"):
    print("here is the date",std1,std1inter,std1college,std1dob)
# Out:
# enter student namealishba
# here is the date alishba khan 81.0 shaikh zaid 14-5-2003
